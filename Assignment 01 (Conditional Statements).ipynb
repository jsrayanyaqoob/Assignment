# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
service=int(input("How many years have you served in our company?"))
salary=float(input("What is your salary"))
bonus=salary + (salary * 0.05)


if service >= 5:
    print(f"Here is the bonus in your salary: ${bonus}")
else:
    print("You have to work for 5 years to get the bonus")
# Out:
# Here is the bonus in your salary: $21000.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age=int(input("What is your age?"))

if age > 17:
    print("You are eligible for voting")
else:
    print("You are not eligible for voting")
# Out:
# You are eligible for voting

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num=int(input("Which number do you want to find is odd or even?"))

if num % 2 == 1:
    print(f"{num} is odd number") 
else:
    print(f"{num} is even number")
# Out:
# 3 is odd number

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
number=int(input("Write a number and I will check if it divisible by 7 or not."))

if number % 7 == 0:
    print(f"{number} is divisble by 7")
else:
    print(f"{number} is not divisible by 7")
# Out:
# 28 is divisble by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num=int(input("Write a number which is multiple of 5"))

if num % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# 6. Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length=int(input("What is the length of your shape"))
breadth=int(input("What is the breadth of your shape"))

if length == breadth:
    print("Your shape is square")
else:
    print("Your shape is rectangle")
# Out:
# Your shape is rectangle

# %% [markdown]
# 7. Take two int values from user and print greatest among them.

# %%
val1=int(input("What is your first value"))
val2=int(input("What is your second value"))

if val1 > val2:
    print(f"{val1} is greater than {val2}")
else:
    print(f"{val2} is greater than {val1}")
# Out:
# 12 is greater than 8

# %% [markdown]
# 8. A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks=int(input("What are your marks"))

if marks < 25:
    print("Your grade is F")
elif marks < 45:
    print("Your grade is E")
elif marks < 50:
    print("Your grade is D")
elif marks < 60:
    print("Your grade is C")
elif marks < 80:
    print("Your grade is B")
else:
    print("Your grade is A")
# Out:
# Your grade is A

# %% [markdown]
# 9. Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age=int(input("What is your age?"))
gender=str(input("What is your gender? M or F?"))
marital_status=str(input("What is your marital status? Y or N?"))

if gender == "F":
    print("You will only work in urban areas")
elif gender == "M":
    if age >= 20 and age <= 40:
        print("You may work anywhere")
    elif age > 40 and age <= 60:
        print("You can only work in urban areas")
else:
    print("Error")
# Out:
# You will only work in urban areas
